# %%
import pandas as pd

# %%
metadata_file = "metadata_cleaned.csv"
metadata = pd.read_csv(metadata_file)

# %%
metadata
# Out:
#    geo_accession  target
# 0      GSM277495  Normal
# 1      GSM277496   tumor
# 2      GSM277497  Normal
# 3      GSM277498   tumor
# 4      GSM277499  Normal
# 5      GSM277500   tumor
# 6      GSM277501  Normal
# 7      GSM277502   tumor
# 8      GSM277503  Normal
# 9      GSM277504   tumor
# 10     GSM277505  Normal
# 11     GSM277506   tumor
# 12     GSM277507  Normal
# 13     GSM277508   tumor
# 14     GSM277509  Normal
# 15     GSM277510   tumor
# 16     GSM277511  Normal
# 17     GSM277512   tumor
# 18     GSM277513  Normal
# 19     GSM277514   tumor
# 20     GSM277515  Normal
# 21     GSM277516   tumor
# 22     GSM277517  Normal
# 23     GSM277518   tumor
# 24     GSM277519  Normal
# 25     GSM277520   tumor
# 26     GSM277521  Normal
# 27     GSM277522   tumor
# 28     GSM277523  Normal
# 29     GSM277524   tumor
# 30     GSM277525  Normal
# 31     GSM277526   tumor
# 32     GSM277527  Normal
# 33     GSM277528   tumor
# 34     GSM277529  Normal
# 35     GSM277530   tumor
# 36     GSM277531  Normal
# 37     GSM277532   tumor
# 38     GSM277533  Normal
# 39     GSM277534   tumor
# 40     GSM277535  Normal
# 41     GSM277536   tumor
# 42     GSM277537  Normal
# 43     GSM277538   tumor
# 44     GSM277539  Normal
# 45     GSM277540   tumor
# 46     GSM277541   tumor
# 47     GSM277542  Normal

# %%
class_counts = metadata["target"].value_counts()
print(class_counts)
# Out:
# target
# Normal    24
# tumor     24
# Name: count, dtype: int64

# %%
metadata['target'].replace(['Normal', 'tumor'],
                        [0, 1], inplace=True)

# %%
metadata
# Out:
#    geo_accession  target
# 0      GSM277495       0
# 1      GSM277496       1
# 2      GSM277497       0
# 3      GSM277498       1
# 4      GSM277499       0
# 5      GSM277500       1
# 6      GSM277501       0
# 7      GSM277502       1
# 8      GSM277503       0
# 9      GSM277504       1
# 10     GSM277505       0
# 11     GSM277506       1
# 12     GSM277507       0
# 13     GSM277508       1
# 14     GSM277509       0
# 15     GSM277510       1
# 16     GSM277511       0
# 17     GSM277512       1
# 18     GSM277513       0
# 19     GSM277514       1
# 20     GSM277515       0
# 21     GSM277516       1
# 22     GSM277517       0
# 23     GSM277518       1
# 24     GSM277519       0
# 25     GSM277520       1
# 26     GSM277521       0
# 27     GSM277522       1
# 28     GSM277523       0
# 29     GSM277524       1
# 30     GSM277525       0
# 31     GSM277526       1
# 32     GSM277527       0
# 33     GSM277528       1
# 34     GSM277529       0
# 35     GSM277530       1
# 36     GSM277531       0
# 37     GSM277532       1
# 38     GSM277533       0
# 39     GSM277534       1
# 40     GSM277535       0
# 41     GSM277536       1
# 42     GSM277537       0
# 43     GSM277538       1
# 44     GSM277539       0
# 45     GSM277540       1
# 46     GSM277541       1
# 47     GSM277542       0

# %%
# Save the cleaned metadata to a new CSV file
output_file = "GSE10950_target_metadata.csv"
metadata.to_csv(output_file, index=False)

print(f"Cleaned metadata saved to {output_file}")
# Out:
# Cleaned metadata saved to GSE10950_target_metadata.csv
