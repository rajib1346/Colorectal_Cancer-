# %%
from google.colab import files
uploaded = files.upload()  # Manually upload the file
# Out:
#      <input type="file" id="files-fb771dff-c3d9-40fc-9c3f-ed308d673e87" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fb771dff-c3d9-40fc-9c3f-ed308d673e87">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()  # Manually upload the file
# Out:
#      <input type="file" id="files-053b8a22-5329-4dfc-8c68-3661aaf69056" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-053b8a22-5329-4dfc-8c68-3661aaf69056">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()  # Manually upload the file
# Out:
#      <input type="file" id="files-1007a82a-603e-4d7c-ad22-49f4aa773647" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1007a82a-603e-4d7c-ad22-49f4aa773647">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()  # Manually upload the file
# Out:
#      <input type="file" id="files-34817f26-a7df-4347-9564-a0fd00f62af7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-34817f26-a7df-4347-9564-a0fd00f62af7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()  # Manually upload the file
# Out:
#      <input type="file" id="files-e20247ca-a2dd-4b6d-b1d4-f3c2ee871d88" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e20247ca-a2dd-4b6d-b1d4-f3c2ee871d88">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # GSE106582

# %% [markdown]
# # MI Feature Selection With Random SearchCV

# %%
[[114   3]
 [  3  74]]

# %% [markdown]
# # 82

# %% [markdown]
# # MI Feature Selection With Random SearchCV Logistic Regression

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


# Given confusion matrix
conf_matrix = np.array([[114  , 3],
 [  3  ,74]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='coolwarm', cbar=True, linewidths=0.5, linecolor='black')
#sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            #xticklabels=class_labels, yticklabels=class_labels)

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("LR")
plt.show()

# %%
[[105  12]
 [  4  73]]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


# Given confusion matrix
conf_matrix = np.array([[112,   5],
 [  3 , 74]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='coolwarm', cbar=True, linewidths=0.5, linecolor='black')
#sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            #xticklabels=class_labels, yticklabels=class_labels)

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("KNN")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


# Given confusion matrix
conf_matrix = np.array([[103 , 14],
 [  3 , 74]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='coolwarm', cbar=True, linewidths=0.5, linecolor='black')
#sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            #xticklabels=class_labels, yticklabels=class_labels)

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("RF")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


# Given confusion matrix
conf_matrix = np.array([[86, 31],
 [ 4, 73]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='coolwarm', cbar=True, linewidths=0.5, linecolor='black')
#sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            #xticklabels=class_labels, yticklabels=class_labels)

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("GradientBoost")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


# Given confusion matrix
conf_matrix = np.array([[111  , 6],
 [  8  ,69]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='coolwarm', cbar=True, linewidths=0.5, linecolor='black')
#sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            #xticklabels=class_labels, yticklabels=class_labels)

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("AdaBoost")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


# Given confusion matrix
conf_matrix = np.array([[104,  13],
 [  3 , 74]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='coolwarm', cbar=True, linewidths=0.5, linecolor='black')
#sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            #xticklabels=class_labels, yticklabels=class_labels)

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Bagging")
plt.show()

# %%
[[108   9]
 [  3  74]]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


# Given confusion matrix
conf_matrix = np.array([[109 ,  8],
 [  3 , 74]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='coolwarm', cbar=True, linewidths=0.5, linecolor='black')
#sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            #xticklabels=class_labels, yticklabels=class_labels)

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Extra Trees")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


# Given confusion matrix
conf_matrix = np.array([[111 ,  6],
 [  4 , 73]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='coolwarm', cbar=True, linewidths=0.5, linecolor='black')
#sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            #xticklabels=class_labels, yticklabels=class_labels)

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("XGBoost")
plt.show()

# %% [markdown]
# # 15 Dataset

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Given confusion matrix
conf_matrix = np.array([[  8 ,  1],
 [  0 ,132]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='cividis', cbar=True, linewidths=0.5, linecolor='black')

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("LR")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Given confusion matrix
conf_matrix = np.array([[  6  , 3],
 [  0 ,132]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='cividis', cbar=True, linewidths=0.5, linecolor='black')

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("KNN")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Given confusion matrix
conf_matrix = np.array([[  5  , 4],
 [  0, 132]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='cividis', cbar=True, linewidths=0.5, linecolor='black')

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("RF")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Given confusion matrix
conf_matrix = np.array([[  7 ,  2],
 [  0 ,132]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='cividis', cbar=True, linewidths=0.5, linecolor='black')

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("GradientBoost")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Given confusion matrix
conf_matrix = np.array([[  7 ,  2],
 [  0 ,132]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='cividis', cbar=True, linewidths=0.5, linecolor='black')

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("AdaBoost")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Given confusion matrix
conf_matrix = np.array([[  5 ,  4],
 [  0 ,132]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='cividis', cbar=True, linewidths=0.5, linecolor='black')

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Bagging")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Given confusion matrix
conf_matrix = np.array([[  8 ,  1],
 [  0 ,132]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='cividis', cbar=True, linewidths=0.5, linecolor='black')

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Extra Trees")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Given confusion matrix
conf_matrix = np.array([[  7  , 2],
 [  0 ,132]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='cividis', cbar=True, linewidths=0.5, linecolor='black')

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("XGBoost")
plt.show()

# %% [markdown]
# # GSE 44076

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Given confusion matrix
conf_matrix = np.array([[50 , 0],
 [ 2 ,96]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Spectral', cbar=True, linewidths=0.5, linecolor='black')

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("LR")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Given confusion matrix
conf_matrix = np.array([[49 , 1],
 [ 1 ,97]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Spectral', cbar=True, linewidths=0.5, linecolor='black')

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("KNN")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Given confusion matrix
conf_matrix = np.array([[46,  4],
 [ 4 ,94]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Spectral', cbar=True, linewidths=0.5, linecolor='black')

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("RF")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Given confusion matrix
conf_matrix = np.array([[47,  3],
 [ 2, 96]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Spectral', cbar=True, linewidths=0.5, linecolor='black')

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("GradientBoost")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Given confusion matrix
conf_matrix = np.array([[50 , 0],
 [ 1, 97]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Spectral', cbar=True, linewidths=0.5, linecolor='black')

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("AdaBoost")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Given confusion matrix
conf_matrix = np.array([[43,  7],
 [ 5 ,93]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Spectral', cbar=True, linewidths=0.5, linecolor='black')

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Bagging")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Given confusion matrix
conf_matrix = np.array([[45,  5],
 [ 8, 90]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Spectral', cbar=True, linewidths=0.5, linecolor='black')

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Extra Trees")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Given confusion matrix
conf_matrix = np.array([[29, 21],
 [ 7, 91]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Spectral', cbar=True, linewidths=0.5, linecolor='black')

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("XGBoost")
plt.show()

# %% [markdown]
# # GSE 71

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Given confusion matrix
conf_matrix = np.array([[32 , 0],
 [ 2 ,30]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='seismic', cbar=True, linewidths=0.5, linecolor='black')

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("LR")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Given confusion matrix
conf_matrix = np.array([[32,  0],
 [ 3 ,29]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='seismic', cbar=True, linewidths=0.5, linecolor='black')

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("KNN")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Given confusion matrix
conf_matrix = np.array([[32,  0],
 [ 1, 31]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='seismic', cbar=True, linewidths=0.5, linecolor='black')

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("RF")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Given confusion matrix
conf_matrix = np.array([[32,  0],
 [ 0 ,32]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='seismic', cbar=True, linewidths=0.5, linecolor='black')

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("GradientBoost")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Given confusion matrix
conf_matrix = np.array([[32,  0],
 [ 0 ,32]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='seismic', cbar=True, linewidths=0.5, linecolor='black')

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("AdaBoost")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Given confusion matrix
conf_matrix = np.array([[32,  0],
 [ 0 ,32]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='seismic', cbar=True, linewidths=0.5, linecolor='black')

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Bagging")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Given confusion matrix
conf_matrix = np.array([[32 , 0],
 [ 7, 25]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='seismic', cbar=True, linewidths=0.5, linecolor='black')

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Extra Trees")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Given confusion matrix
conf_matrix = np.array([[32 , 0],
 [ 0, 32]])

# Define class labels
class_labels = ["Class 0", "Class 1"]

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='seismic', cbar=True, linewidths=0.5, linecolor='black')

# Labels and title
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("XGBoost")
plt.show()
